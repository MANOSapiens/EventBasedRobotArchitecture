# %%
from StartExecution import start_execution
from Port import PortDefinition
from pybricks.parameters import Port
from pybricks.hubs import PrimeHub
from Logger import Notetaker
import cProfile

# %%
port_definitions = PortDefinition(
        l_drive_port=Port.A,
        r_drive_port=Port.B,
        l_tool_port=Port.C,
        r_tool_port=Port.D,
        colour_port=Port.E,
    )

# %%
hub = PrimeHub.PrimeHub()
notetaker = Notetaker('log.txt')
cProfile.run("start_execution(hub, 'instructions/Runde2ORANGE.json', port_definitions, [], [], [], notetaker)")
# Out:
# Spawned 1
# Spawned 2
# Spawned 3
# Spawned 4
# Spawned 7
# Spawned 8
# Spawned 9
# Spawned 10
# Spawned 11
# Spawned 12
# Spawned 13
# Spawned 14
# Terminated 11
# Terminated 14
# Terminated 9
# Terminated 12
# Terminated 10
# Terminated 13
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 7
# Terminated 1
# Terminated 2
# Terminated 3
# Terminated 4
# Terminated 8
# Spawned 5
# Spawned 6
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 5
# Terminated 6
# Spawned 15
# Spawned 16
# Spawned 17
# Terminated 17
# Terminated 15
# Terminated 16
# Spawned 18
# Spawned 19
# Spawned 20
# Terminated 20
# Terminated 18
# Terminated 19
# Spawned 21
# Spawned 22
# Spawned 23
# Spawned 24
# Spawned 27
# Terminated 27
# Terminated 21
# Terminated 22
# Terminated 23
# Terminated 24
# Spawned 25
# Spawned 26
# Spawned 28
# Spawned 29
# Spawned 30
# Spawned 31
# Spawned 34
# Spawned 35
# Spawned 51
# Spawned 52
# Spawned 53
# Terminated 25
# Terminated 26
# Terminated 34
# Terminated 28
# Terminated 29
# Terminated 30
# Terminated 31
# Terminated 35
# Spawned 32
# Spawned 33
# Spawned 36
# Spawned 37
# Spawned 38
# Spawned 39
# Spawned 42
# Terminated 32
# Terminated 33
# Terminated 53
# Terminated 51
# Terminated 52
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 42
# Terminated 36
# Terminated 37
# Terminated 38
# Terminated 39
# Spawned 40
# Spawned 41
# Spawned 43
# Spawned 44
# Spawned 45
# Spawned 46
# Spawned 49
# Spawned 50
# Terminated 40
# Terminated 41
# Terminated 49
# Terminated 43
# Terminated 44
# Terminated 45
# Terminated 46
# Terminated 50
# Spawned 47
# Spawned 48
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 47
# Terminated 48
# Spawned 54
# Spawned 72
# Spawned 73
# Spawned 74
# Terminated 54
# Spawned 55
# Spawned 56
# Spawned 57
# Spawned 58
# Spawned 61
# Spawned 62
# Terminated 55
# Terminated 57
# Terminated 58
# Spawned 59
# Spawned 60
# Terminated 61
# Terminated 56
# Terminated 59
# Terminated 60
# Terminated 62
# Spawned 63
# Spawned 64
# Spawned 65
# Spawned 66
# Spawned 69
# Spawned 70
# Terminated 63
# Terminated 65
# Terminated 66
# Spawned 67
# Spawned 68
# Terminated 69
# Terminated 64
# Terminated 67
# Terminated 68
# Terminated 70
# Spawned 71
# Terminated 71
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 74
# Terminated 72
# Terminated 73
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 75
# Spawned 76
# Spawned 77
# Spawned 78
# Spawned 81
# Terminated 81
# Terminated 75
# Terminated 76
# Terminated 77
# Terminated 78
# Spawned 79
# Spawned 80
# Spawned 82
# Spawned 83
# Spawned 84
# Spawned 85
# Spawned 88
# Spawned 89
# Terminated 79
# Terminated 80
# Terminated 88
# Terminated 82
# Terminated 83
# Terminated 84
# Terminated 85
# Terminated 89
# Spawned 86
# Spawned 87
# Spawned 90
# Spawned 91
# Spawned 92
# Terminated 86
# Terminated 87
# Terminated 92
# Terminated 90
# Terminated 91
# Spawned 93
# Terminated 93
# Spawned 94
# Spawned 95
# Spawned 96
# Terminated 96
# Terminated 94
# Terminated 95
# Spawned 97
# Spawned 98
# Spawned 99
# Spawned 100
# Spawned 103
# Terminated 103
# Terminated 97
# Terminated 98
# Terminated 99
# Terminated 100
# Spawned 101
# Spawned 102
# Spawned 104
# Spawned 105
# Spawned 106
# Spawned 107
# Spawned 110
# Spawned 111
# Terminated 101
# Terminated 102
# Terminated 110
# Terminated 104
# Terminated 105
# Terminated 106
# Terminated 107
# Terminated 111
# Spawned 108
# Spawned 109
# Spawned 112
# Spawned 113
# Spawned 114
# Spawned 115
# Spawned 118
# Terminated 112
# Terminated 113
# Terminated 108
# Terminated 109
# Terminated 114
# Terminated 115
# Spawned 116
# Spawned 117
# Spawned 119
# Spawned 120
# Spawned 121
# Spawned 122
# Spawned 125
# Spawned 126
# Terminated 116
# Terminated 117
# Terminated 125
# Terminated 119
# Terminated 120
# Terminated 121
# Terminated 122
# Terminated 126
# Spawned 123
# Spawned 124
# Spawned 127
# Spawned 128
# Spawned 129
# Terminated 123
# Terminated 124
# Terminated 118
# Terminated 129
# Terminated 127
# Terminated 128
# Spawned 130
# Spawned 131
# Spawned 132
# Terminated 132
# Terminated 130
# Terminated 131
# Spawned 133
# Spawned 134
# Spawned 135
# Spawned 136
# Spawned 139
# Spawned 140
# Terminated 139
# Terminated 133
# Terminated 134
# Terminated 135
# Terminated 136
# Terminated 140
# Spawned 137
# Spawned 138
# Spawned 141
# Spawned 142
# Spawned 143
# Spawned 144
# Spawned 147
# Terminated 141
# Terminated 142
# Terminated 137
# Terminated 138
# Terminated 143
# Terminated 144
# Spawned 145
# Spawned 146
# Spawned 148
# Spawned 149
# Spawned 150
# Spawned 151
# Spawned 154
# Spawned 155
# Spawned 156
# Spawned 157
# Spawned 158
# Terminated 145
# Terminated 146
# Terminated 158
# Terminated 156
# Terminated 157
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 154
# Terminated 148
# Terminated 149
# Terminated 150
# Terminated 151
# Terminated 155
# Spawned 152
# Spawned 153
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 152
# Terminated 153
# Spawned 159
# Spawned 160
# Spawned 161
# Terminated 147
# Terminated 161
# Terminated 159
# Terminated 160
# Spawned 162
# Spawned 163
# Spawned 164
# Terminated 164
# Terminated 162
# Terminated 163
# Spawned 165
# Spawned 166
# Spawned 167
# Spawned 168
# Spawned 171
# Spawned 172
# Terminated 171
# Terminated 165
# Terminated 166
# Terminated 167
# Terminated 168
# Terminated 172
# Spawned 169
# Spawned 170
# Spawned 173
# Spawned 174
# Spawned 175
# Spawned 176
# Spawned 179
# Terminated 169
# Terminated 170
# Terminated 179
# Terminated 173
# Terminated 174
# Terminated 175
# Terminated 176
# Spawned 177
# Spawned 178
# Spawned 180
# Spawned 181
# Spawned 182
# Spawned 183
# Spawned 186
# Spawned 187
# Terminated 177
# Terminated 178
# Terminated 186
# Terminated 180
# Terminated 181
# Terminated 182
# Terminated 183
# Terminated 187
# Spawned 184
# Spawned 185
# Spawned 188
# Spawned 189
# Spawned 190
# Spawned 191
# Spawned 194
# Spawned 203
# Spawned 204
# Spawned 205
# Terminated 188
# Terminated 184
# Terminated 185
# Terminated 190
# Terminated 191
# Spawned 192
# Spawned 193
# Terminated 194
# Terminated 189
# Terminated 192
# Terminated 193
# Spawned 195
# Spawned 196
# Spawned 197
# Spawned 198
# Spawned 201
# Spawned 202
# Terminated 205
# Terminated 203
# Terminated 204
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 201
# Terminated 195
# Terminated 196
# Terminated 197
# Terminated 198
# Terminated 202
# Spawned 199
# Spawned 200
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 199
# Terminated 200
# Spawned 206
# Spawned 207
# Spawned 208
# Terminated 208
# Terminated 206
# Terminated 207
# Spawned 209
# Spawned 210
# Spawned 211
# Spawned 212
# Spawned 215
# Terminated 215
# Terminated 209
# Terminated 210
# Terminated 211
# Terminated 212
# Spawned 213
# Spawned 214
# Spawned 216
# Spawned 217
# Spawned 218
# Spawned 219
# Spawned 222
# Spawned 223
# Terminated 213
# Terminated 214
# Terminated 222
# Terminated 216
# Terminated 217
# Terminated 218
# Terminated 219
# Terminated 223
# Spawned 220
# Spawned 221
# Spawned 224
# Terminated 220
# Terminated 221
#          30753642 function calls in 71.392 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:186(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#        12    0.000    0.000    0.000    0.000 <frozen codecs>:276(reset)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:319(decode)
#        12    0.000    0.000    0.000    0.000 <frozen codecs>:327(reset)
#         1    0.000    0.000   71.392   71.392 <string>:1(<module>)
#     63319    0.018    0.000    0.018    0.000 Actuators.py:27(constrain_actuator_values)
#    114187    0.256    0.000    0.284    0.000 Actuators.py:35(write_to_actuators)
#    298962    0.153    0.000    0.153    0.000 Actuators.py:5(set_motor_pow)
#    114187    0.143    0.000    0.143    0.000 Check.py:14(check)
#         1    0.000    0.000    0.000    0.000 Check.py:5(__init__)
#         1    0.000    0.000    0.000    0.000 Events.py:114(__init__)
#       612    0.000    0.000    0.000    0.000 Events.py:12(__init__)
#         1    0.000    0.000    0.000    0.000 Events.py:121(__init__)
#       415    0.000    0.000    0.000    0.000 Events.py:129(__init__)
#        21    0.000    0.000    0.000    0.000 Events.py:138(__init__)
#        61    0.000    0.000    0.000    0.000 Events.py:148(__init__)
#        12    0.000    0.000    0.000    0.000 Events.py:167(__init__)
#        14    0.000    0.000    0.000    0.000 Events.py:18(__init__)
#       102    0.000    0.000    0.000    0.000 Events.py:183(__init__)
#        15    0.000    0.000    0.000    0.000 Events.py:28(__init__)
#        92    0.000    0.000    0.000    0.000 Events.py:33(__init__)
#        61    0.000    0.000    0.000    0.000 Events.py:56(__init__)
#       224    0.000    0.000    0.000    0.000 Events.py:6(__init__)
#       107    0.000    0.000    0.000    0.000 Events.py:66(__init__)
#        14    0.000    0.000    0.000    0.000 Events.py:74(__init__)
#        41    0.000    0.000    0.000    0.000 Events.py:98(__init__)
#         1    0.000    0.000    0.000    0.000 Logger.py:23(init_logger)
#         1    0.000    0.000    0.000    0.000 Logger.py:28(log_header_csv)
#    114187    0.311    0.000    3.053    0.000 Logger.py:50(log_csv)
#        12    0.000    0.000    0.000    0.000 Logger.py:9(log)
#     41568    0.100    0.000    0.100    0.000 PID.py:4(compute_pid)
#         1    0.000    0.000    0.000    0.000 Port.py:14(__init__)
#         1    0.000    0.000    0.000    0.000 Port.py:47(prepare_motors_sensor)
#         1    0.000    0.000    0.000    0.000 Port.py:79(set_speed_pid)
#     78095    0.011    0.000    0.011    0.000 PrimeHub.py:5(heading)
#         1    0.000    0.000    0.000    0.000 PrimeHub.py:8(reset_heading)
#         1    0.000    0.000    0.000    0.000 ProcessLoop.py:14(__init__)
#         1    0.000    0.000    0.000    0.000 ProcessLoop.py:71(terminate_process_loop)
#         1    0.389    0.389   71.377   71.377 ProcessLoop.py:94(process_loop)
#       634    0.000    0.000    0.000    0.000 ReadInstructions.py:13(parse_f32)
#       612    0.001    0.000    0.005    0.000 ReadInstructions.py:154(match_cond)
#      1004    0.000    0.000    0.000    0.000 ReadInstructions.py:18(parse_string)
#         1    0.001    0.001    0.014    0.014 ReadInstructions.py:208(read_instructions)
#         1    0.000    0.000    0.000    0.000 ReadInstructions.py:236(generate_name)
#       224    0.001    0.000    0.001    0.000 ReadInstructions.py:24(read_event)
#       612    0.002    0.000    0.003    0.000 ReadInstructions.py:32(read_cond)
#       107    0.000    0.000    0.001    0.000 ReadInstructions.py:40(read_func)
#        14    0.000    0.000    0.000    0.000 ReadInstructions.py:64(read_pid)
#       224    0.001    0.000    0.003    0.000 ReadInstructions.py:75(match_event)
#      3423    0.001    0.000    0.001    0.000 ReadInstructions.py:8(parse_int)
#    504726    0.573    0.000    0.573    0.000 ReadSensors.py:16(get_sensor_value)
#    114187    0.849    0.000    4.017    0.000 ReadSensors.py:71(read_sensors)
#         1    0.000    0.000    0.000    0.000 ReadSensors.py:9(reset_all)
#    463369    0.439    0.000    0.439    0.000 RunEvents.py:28(set_read_sensor)
#    114187   18.693    0.000   20.192    0.000 RunEvents.py:58(run_events)
#    215826    0.222    0.000    0.247    0.000 RunEvents.py:9(math_func)
#  14544024    5.153    0.000    5.162    0.000 SpawnTerminateEvents.py:13(set_var_term)
#    114187   17.220    0.000   21.284    0.000 SpawnTerminateEvents.py:21(spawn_events)
#  12789345    4.059    0.000    4.064    0.000 SpawnTerminateEvents.py:4(set_var_spawn)
#    114187   19.904    0.000   25.066    0.000 SpawnTerminateEvents.py:41(terminate_events)
#         1    0.000    0.000   71.391   71.391 StartExecution.py:15(start_execution)
#         1    0.000    0.000    0.004    0.004 __init__.py:274(load)
#         1    0.000    0.000    0.004    0.004 __init__.py:299(loads)
#         1    0.000    0.000    0.004    0.004 decoder.py:332(decode)
#         1    0.004    0.004    0.004    0.004 decoder.py:343(raw_decode)
#        40    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#        40    0.000    0.000    0.003    0.000 iostream.py:259(schedule)
#      1956    0.001    0.000    0.002    0.000 iostream.py:521(_is_master_process)
#      1956    0.001    0.000    0.004    0.000 iostream.py:548(_schedule_flush)
#      1956    0.006    0.000    0.013    0.000 iostream.py:626(write)
#        18    0.000    0.000    0.000    0.000 pupdevices.py:11(brake)
#    142788    0.019    0.000    0.019    0.000 pupdevices.py:17(angle)
#         4    0.000    0.000    0.000    0.000 pupdevices.py:2(__init__)
#    228372    0.026    0.000    0.026    0.000 pupdevices.py:20(speed)
#         4    0.000    0.000    0.000    0.000 pupdevices.py:23(reset_angle)
#     63274    0.009    0.000    0.009    0.000 pupdevices.py:5(run)
#        27    0.000    0.000    0.000    0.000 pupdevices.py:8(dc)
#         2    0.000    0.000    0.000    0.000 random.py:235(_randbelow_with_getrandbits)
#         2    0.000    0.000    0.000    0.000 random.py:367(choice)
#        40    0.003    0.000    0.003    0.000 socket.py:621(send)
#        40    0.000    0.000    0.000    0.000 threading.py:1118(_wait_for_tstate_lock)
#        40    0.000    0.000    0.000    0.000 threading.py:1185(is_alive)
#        40    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.writer}
#         1    0.000    0.000   71.392   71.392 {built-in method builtins.exec}
#      2962    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#      1970    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       489    0.002    0.000    0.014    0.000 {built-in method builtins.print}
#     35955    0.025    0.000    0.025    0.000 {built-in method builtins.round}
#         2    0.001    0.000    0.001    0.000 {built-in method io.open}
#      1956    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#    228379    0.047    0.000    0.047    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#      1956    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        40    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       836    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#    114200    1.907    0.000    1.907    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       836    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         2    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#      1956    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        12    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#    114188    0.835    0.000    0.835    0.000 {method 'writerow' of '_csv.writer' objects}
