# %%
from StartExecution import start_execution
from Port import PortDefinition
from pybricks.parameters import Port
from pybricks.hubs import PrimeHub
from Logger import Notetaker

# %%
port_definitions = PortDefinition(
        l_drive_port=Port.A,
        r_drive_port=Port.B,
        l_tool_port=Port.C,
        r_tool_port=Port.D,
        colour_port=Port.E,
    )

# %%
hub = PrimeHub.PrimeHub()
notetaker = Notetaker('log.txt')
start_execution(hub, 'instructions/Runde2ORANGE.json', port_definitions, [], [], [], notetaker)
# Out:
# Spawned 1
# Spawned 2
# Spawned 3
# Spawned 4
# Spawned 7
# Spawned 8
# Spawned 9
# Spawned 10
# Spawned 11
# Spawned 12
# Spawned 13
# Spawned 14
# Terminated 11
# Terminated 14
# Terminated 9
# Terminated 12
# Terminated 10
# Terminated 13
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 7
# Terminated 1
# Terminated 2
# Terminated 3
# Terminated 4
# Terminated 8
# Spawned 5
# Spawned 6
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 5
# Terminated 6
# Spawned 15
# Spawned 16
# Spawned 17
# Terminated 17
# Terminated 15
# Terminated 16
# Spawned 18
# Spawned 19
# Spawned 20
# Terminated 20
# Terminated 18
# Terminated 19
# Spawned 21
# Spawned 22
# Spawned 23
# Spawned 24
# Spawned 27
# Terminated 27
# Terminated 21
# Terminated 22
# Terminated 23
# Terminated 24
# Spawned 25
# Spawned 26
# Spawned 28
# Spawned 29
# Spawned 30
# Spawned 31
# Spawned 34
# Spawned 35
# Spawned 51
# Spawned 52
# Spawned 53
# Terminated 25
# Terminated 26
# Terminated 34
# Terminated 28
# Terminated 29
# Terminated 30
# Terminated 31
# Terminated 35
# Spawned 32
# Spawned 33
# Spawned 36
# Spawned 37
# Spawned 38
# Spawned 39
# Spawned 42
# Terminated 32
# Terminated 33
# Terminated 53
# Terminated 51
# Terminated 52
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 42
# Terminated 36
# Terminated 37
# Terminated 38
# Terminated 39
# Spawned 40
# Spawned 41
# Spawned 43
# Spawned 44
# Spawned 45
# Spawned 46
# Spawned 49
# Spawned 50
# Terminated 40
# Terminated 41
# Terminated 49
# Terminated 43
# Terminated 44
# Terminated 45
# Terminated 46
# Terminated 50
# Spawned 47
# Spawned 48
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 47
# Terminated 48
# Spawned 54
# Spawned 72
# Spawned 73
# Spawned 74
# Terminated 54
# Spawned 55
# Spawned 56
# Spawned 57
# Spawned 58
# Spawned 61
# Spawned 62
# Terminated 55
# Terminated 57
# Terminated 58
# Spawned 59
# Spawned 60
# Terminated 61
# Terminated 56
# Terminated 59
# Terminated 60
# Terminated 62
# Spawned 63
# Spawned 64
# Spawned 65
# Spawned 66
# Spawned 69
# Spawned 70
# Terminated 63
# Terminated 65
# Terminated 66
# Spawned 67
# Spawned 68
# Terminated 69
# Terminated 64
# Terminated 67
# Terminated 68
# Terminated 70
# Spawned 71
# Terminated 71
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 74
# Terminated 72
# Terminated 73
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 75
# Spawned 76
# Spawned 77
# Spawned 78
# Spawned 81
# Terminated 81
# Terminated 75
# Terminated 76
# Terminated 77
# Terminated 78
# Spawned 79
# Spawned 80
# Spawned 82
# Spawned 83
# Spawned 84
# Spawned 85
# Spawned 88
# Spawned 89
# Terminated 79
# Terminated 80
# Terminated 88
# Terminated 82
# Terminated 83
# Terminated 84
# Terminated 85
# Terminated 89
# Spawned 86
# Spawned 87
# Spawned 90
# Spawned 91
# Spawned 92
# Terminated 86
# Terminated 87
# Terminated 92
# Terminated 90
# Terminated 91
# Spawned 93
# Terminated 93
# Spawned 94
# Spawned 95
# Spawned 96
# Terminated 96
# Terminated 94
# Terminated 95
# Spawned 97
# Spawned 98
# Spawned 99
# Spawned 100
# Spawned 103
# Terminated 103
# Terminated 97
# Terminated 98
# Terminated 99
# Terminated 100
# Spawned 101
# Spawned 102
# Spawned 104
# Spawned 105
# Spawned 106
# Spawned 107
# Spawned 110
# Spawned 111
# Terminated 101
# Terminated 102
# Terminated 110
# Terminated 104
# Terminated 105
# Terminated 106
# Terminated 107
# Terminated 111
# Spawned 108
# Spawned 109
# Spawned 112
# Spawned 113
# Spawned 114
# Spawned 115
# Spawned 118
# Terminated 112
# Terminated 113
# Terminated 108
# Terminated 109
# Terminated 114
# Terminated 115
# Spawned 116
# Spawned 117
# Spawned 119
# Spawned 120
# Spawned 121
# Spawned 122
# Spawned 125
# Spawned 126
# Terminated 116
# Terminated 117
# Terminated 125
# Terminated 119
# Terminated 120
# Terminated 121
# Terminated 122
# Terminated 126
# Spawned 123
# Spawned 124
# Spawned 127
# Spawned 128
# Spawned 129
# Terminated 123
# Terminated 124
# Terminated 118
# Terminated 129
# Terminated 127
# Terminated 128
# Spawned 130
# Spawned 131
# Spawned 132
# Terminated 132
# Terminated 130
# Terminated 131
# Spawned 133
# Spawned 134
# Spawned 135
# Spawned 136
# Spawned 139
# Spawned 140
# Terminated 139
# Terminated 133
# Terminated 134
# Terminated 135
# Terminated 136
# Terminated 140
# Spawned 137
# Spawned 138
# Spawned 141
# Spawned 142
# Spawned 143
# Spawned 144
# Spawned 147
# Terminated 141
# Terminated 142
# Terminated 137
# Terminated 138
# Terminated 143
# Terminated 144
# Spawned 145
# Spawned 146
# Spawned 148
# Spawned 149
# Spawned 150
# Spawned 151
# Spawned 154
# Spawned 155
# Spawned 156
# Spawned 157
# Spawned 158
# Terminated 145
# Terminated 146
# Terminated 158
# Terminated 156
# Terminated 157
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 154
# Terminated 148
# Terminated 149
# Terminated 150
# Terminated 151
# Terminated 155
# Spawned 152
# Spawned 153
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 152
# Terminated 153
# Spawned 159
# Spawned 160
# Spawned 161
# Terminated 147
# Terminated 161
# Terminated 159
# Terminated 160
# Spawned 162
# Spawned 163
# Spawned 164
# Terminated 164
# Terminated 162
# Terminated 163
# Spawned 165
# Spawned 166
# Spawned 167
# Spawned 168
# Spawned 171
# Spawned 172
# Terminated 171
# Terminated 165
# Terminated 166
# Terminated 167
# Terminated 168
# Terminated 172
# Spawned 169
# Spawned 170
# Spawned 173
# Spawned 174
# Spawned 175
# Spawned 176
# Spawned 179
# Terminated 169
# Terminated 170
# Terminated 179
# Terminated 173
# Terminated 174
# Terminated 175
# Terminated 176
# Spawned 177
# Spawned 178
# Spawned 180
# Spawned 181
# Spawned 182
# Spawned 183
# Spawned 186
# Spawned 187
# Terminated 177
# Terminated 178
# Terminated 186
# Terminated 180
# Terminated 181
# Terminated 182
# Terminated 183
# Terminated 187
# Spawned 184
# Spawned 185
# Spawned 188
# Spawned 189
# Spawned 190
# Spawned 191
# Spawned 194
# Spawned 203
# Spawned 204
# Spawned 205
# Terminated 188
# Terminated 184
# Terminated 185
# Terminated 190
# Terminated 191
# Spawned 192
# Spawned 193
# Terminated 194
# Terminated 189
# Terminated 192
# Terminated 193
# Spawned 195
# Spawned 196
# Spawned 197
# Spawned 198
# Spawned 201
# Spawned 202
# Terminated 205
# Terminated 203
# Terminated 204
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 201
# Terminated 195
# Terminated 196
# Terminated 197
# Terminated 198
# Terminated 202
# Spawned 199
# Spawned 200
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 199
# Terminated 200
# Spawned 206
# Spawned 207
# Spawned 208
# Terminated 208
# Terminated 206
# Terminated 207
# Spawned 209
# Spawned 210
# Spawned 211
# Spawned 212
# Spawned 215
# Terminated 215
# Terminated 209
# Terminated 210
# Terminated 211
# Terminated 212
# Spawned 213
# Spawned 214
# Spawned 216
# Spawned 217
# Spawned 218
# Spawned 219
# Spawned 222
# Spawned 223
# Terminated 213
# Terminated 214
# Terminated 222
# Terminated 216
# Terminated 217
# Terminated 218
# Terminated 219
# Terminated 223
# Spawned 220
# Spawned 221
# Spawned 224
# Terminated 220
# Terminated 221
# 2

# %%
notetaker = Notetaker('logs.txt')
notetaker.log('s')
