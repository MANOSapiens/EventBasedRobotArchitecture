# %%
from StartExecution import start_execution
from Port import PortDefinition
from pybricks.parameters import Port
from pybricks.hubs import PrimeHub
from Logger import Notetaker
import cProfile

# %%
port_definitions = PortDefinition(
        l_drive_port=Port.A,
        r_drive_port=Port.B,
        l_tool_port=Port.C,
        r_tool_port=Port.D,
        colour_port=Port.E,
    )

# %%
hub = PrimeHub.PrimeHub()
notetaker = Notetaker('log.txt')
cProfile.run("start_execution(hub, 'instructions/Runde2ORANGE.json', port_definitions, [], [], [], notetaker)")
# Out:
# Spawned 1
# Spawned 2
# Spawned 3
# Spawned 4
# Spawned 7
# Spawned 8
# Spawned 9
# Spawned 10
# Spawned 11
# Spawned 12
# Spawned 13
# Spawned 14
# Terminated 11
# Terminated 14
# Terminated 9
# Terminated 12
# Terminated 10
# Terminated 13
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 7
# Terminated 1
# Terminated 2
# Terminated 3
# Terminated 4
# Terminated 8
# Spawned 5
# Spawned 6
# Spawned 0
# Spawned 0
# Spawned 0
# Terminated 5
# Terminated 6
# Spawned 15
# Spawned 16
# Spawned 17
# Terminated 17
# Terminated 15
# Terminated 16
# Spawned 18
# Spawned 19
# Spawned 20
# Terminated 20
# Terminated 18
# Terminated 19
# Spawned 21
# Spawned 22
# Spawned 23
# Spawned 24
# Spawned 27
# Terminated 27
# Terminated 21
# Terminated 22
# Terminated 23
# Terminated 24
# Spawned 25
# Spawned 26
# Spawned 28
# Spawned 29
# Spawned 30
# Spawned 31
# Spawned 34
# Spawned 35
# Spawned 51
# Spawned 52
# Spawned 53
# ...
